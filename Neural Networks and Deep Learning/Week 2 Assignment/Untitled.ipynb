# %%
import h5py
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
f = h5py.File("datasets\\train_catvnoncat.h5",mode= 'r')

# %%
list(f)
# Out:
# ['list_classes', 'train_set_x', 'train_set_y']

# %%
img=f['train_set_x']

# %%
plt.imshow(img[15])
